# %%
import chromadb

# %%
client = chromadb.Client()

# %%
collection = client.create_collection(
    name="documents"
)

# %%
documents = [
    "Machine learning is a branch of AI",
    "Transformers use self attention",
    "Dogs are loyal animals",
    "Python is a programming language",
    "The weather is sunny today"
]

ids = [
    "1",
    "2",
    "3",
    "4",
    "5"
]

collection.add(
    documents=documents,
    ids=ids
)
# Out:
# C:\Users\venuv\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:08<00:00, 9.87MiB/s]

# %%
collection.get()
# Out:
# {'ids': ['1', '2', '3', '4', '5'],
#  'embeddings': None,
#  'documents': ['Machine learning is a branch of AI',
#   'Transformers use self attention',
#   'Dogs are loyal animals',
#   'Python is a programming language',
#   'The weather is sunny today'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None, None, None]}

# %%
results = collection.query(
    query_texts=[
        "How does attention work in transformers?"
    ],
    n_results=2
)
print(results)
# Out:
# {'ids': [['2', '1']], 'embeddings': None, 'documents': [['Transformers use self attention', 'Machine learning is a branch of AI']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[0.33293163776397705, 1.7321525812149048]]}
